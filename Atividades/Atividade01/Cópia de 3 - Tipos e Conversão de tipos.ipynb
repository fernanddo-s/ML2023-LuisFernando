# %% [markdown]
# # 3 - Tipos e Conversão de tipos
# O Numpy suporta uma variedade de tipos muito maior do que o Python.

# %% [markdown]
# Existem 5 tipos básicos numéricos
# - Booleans (bool)
# - Integers (int)
# - Unsigned Intergers (uint)
# - Floating Points (float)
# - Complex
#
# Complementarmente, a célula abaixo mostra um quadro comparativos com uma maior quantidade de tipos do Numpy.

# %% [markdown]
# ![datatypes.png](attachment:datatypes.png)

# %% [markdown]
# Existem diversos tipos básicos numéricos em Python, com o numpy é possível ter uma variedade de tipos muito maior.
# Como existem vários tipos de dados é pssível também fazer a conversão de um tipo para outro, para isso são usadas alguns comandos como o astype(), que recebe como parametro o novo tipo de dado que deseja que seja aplicado ao seu dado anterior. Para saber o tipo de um dado basta usar o comando dtype.

# %%
import numpy as np

# %%
x = np.float32(1.0)
x
# Out:
# 1.0

# %%
y = np.int_([1,2,4])
y
# Out:
# array([1, 2, 4])

# %%
z = np.arange(3, dtype=np.uint8)
z
# Out:
# array([0, 1, 2], dtype=uint8)

# %%
np.array([1, 2, 3], dtype='f')
# Out:
# array([1., 2., 3.], dtype=float32)

# %% [markdown]
# ## Convertendo tipos de arrays

# %% [markdown]
# Para convertermos arrays Numpy, basta utilizarmos o método astype().

# %%
z.astype(float)
# Out:
# array([0., 1., 2.])

# %%
np.int8(z)
# Out:
# array([0, 1, 2], dtype=int8)

# %% [markdown]
# Para verificarmos o tipo de um array Numpy, basta verificarmos o seu atributo dtype.

# %%
z.dtype
# Out:
# dtype('uint8')
