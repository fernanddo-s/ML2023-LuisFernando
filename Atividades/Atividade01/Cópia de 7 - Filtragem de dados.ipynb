# %% [markdown]
# # 7 - Filtragem de dados
# Filtragem de dados é uma tarefa importantíssima na vida de qualquer cientista de dados. Nessa seção, veremos como criar filtros em um conjunto de dados utilizando o Pandas.

# %% [markdown]
# ## Operadores booleanos

# %% [markdown]
# ### and

# %% [markdown]
# and é operador lógico no qual a resposta da operação é verdade se ambas as variáveis de entrada forem verdade.

# %%
x = 12

# %%
x > 5 and x < 15
# Out:
# True

# %% [markdown]
# ### or

# %% [markdown]
# or é operador lógico no qual a resposta da operação é verdade se pelo menos uma das variáveis de entrada for verdade.

# %%
y = 5

# %%
y < 7 or y > 13
# Out:
# True

# %% [markdown]
# ### not

# %% [markdown]
# not é o operador lógico de negação

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %% [markdown]
# ### Numpy

# %% [markdown]
# Definindo dois array diferentes, depois fazendo a divisão de um pelo outro ao quadrado.

# %%
import numpy as np

np_height = np.array([1.73, 1.68, 1.71, 1.89, 1.79])
np_weight = np.array([65.4, 59.2, 63.6, 88.4, 68.7])
bmi = np_weight / np_height ** 2

bmi
# Out:
# array([21.85171573, 20.97505669, 21.75028214, 24.7473475 , 21.44127836])

# %% [markdown]
# Quais indices apresentam um número maior que 21, o operador retorna uma array com true ou false de acordo com cada indice do array que corresponde á inferência lógica.

# %%
bmi > 21
# Out:
# array([ True, False,  True,  True,  True])

# %% [markdown]
# Testa se todos os elementos da matriz ao longo de um determinado eixo corresponde a inferência lógica. Nesse caso esta sendo verificado se todos os números estão no intevelo de 21 a 22.

# %%
bmi.all() > 21 and bmi.all() < 22
# Out:
# False

# %% [markdown]
# Nesse caso esta sendo verificado se todos os números estão no intevelo de 21 a 22. E o retorno é de acordo com o indice e mostra se o número correspondente do array está ou não de acordo com a inferência lógica.

# %%
np.logical_and(bmi > 21, bmi < 22)
# Out:
# array([ True, False,  True, False,  True])

# %% [markdown]
# Nesse caso esta sendo verificado se todos os números estão no intevelo de 21 a 22. E o retorno são os números do array que estão de acordo com a inferência lógica.

# %%
bmi[np.logical_and(bmi > 21, bmi < 22)]
# Out:
# array([21.85171573, 21.75028214, 21.44127836])

# %% [markdown]
# ## Filtrando um DataFrame Pandas

# %% [markdown]
# Carregando e mostrando os dados do arquivo .csv

# %%
import pandas as pd
brics = pd.read_csv('brics.csv', index_col=0)
brics
# Out:
#          country    capital    area  population
# BR        Brazil   Brasilia   8.516      200.40
# RU        Russia     Moscow  17.100      143.50
# IN         India  New Delhi   3.286     1252.00
# CH         China    Beijing   9.597     1357.00
# SA  South Africa   Pretoria   1.221       52.98

# %% [markdown]
# **Objetivo**: selecionar os países com área maior do que 8 milhões de km2
#
# 3 passos:
# - Selecionar a coluna "area"
# - Fazer uma comparação na coluna "area"
# - Usar o resultado para selecionar os países

# %%
# Selecionar a coluna "area"
brics['area']
# Out:
# BR     8.516
# RU    17.100
# IN     3.286
# CH     9.597
# SA     1.221
# Name: area, dtype: float64

# %%
# Fazer uma comparação na coluna "area"
brics['area'] > 8
is_huge = brics['area'] > 8
is_huge
# Out:
# BR     True
# RU     True
# IN    False
# CH     True
# SA    False
# Name: area, dtype: bool

# %%
# Usar o resultado para selecionar os países
brics[is_huge]
# Out:
#    country   capital    area  population
# BR  Brazil  Brasilia   8.516       200.4
# RU  Russia    Moscow  17.100       143.5
# CH   China   Beijing   9.597      1357.0

# %%
# Importando dataset de carros
import pandas as pd
cars = pd.read_csv('cars.csv', index_col = 0)
cars
# Out:
#      cars_per_cap        country  drives_right
# US            809  United States          True
# AUS           731      Australia         False
# JAP           588          Japan         False
# IN             18          India         False
# RU            200         Russia          True
# MOR            70        Morocco          True
# EG             45          Egypt          True

# %%
# Extraia a coluna 'drives_right' do DataFrame 'cars' e atribua a variável 'dr'
dr = cars['drives_right']

# Use a variável 'dr' para criar um subconjunto de dados chamado 'sel'
sel = cars[dr]

# Imprima a variável 'sel'
print(sel)
# Out:
#      cars_per_cap        country  drives_right
# US            809  United States          True
# RU            200         Russia          True
# MOR            70        Morocco          True
# EG             45          Egypt          True

# %%
# Crie uma variável car_maniac: linhas que possuem 'cars_per_cap' maiores do que 500
cpc = cars['cars_per_cap']
many_cars = cpc > 500
car_maniac = cars[many_cars]

# Imprima 'car_maniac'
print(car_maniac)
# Out:
#      cars_per_cap        country  drives_right
# US            809  United States          True
# AUS           731      Australia         False
# JAP           588          Japan         False

# %%
# Importe o conjunto de dados 'cars.csv', bem como as bibliotecas 'pandas' e 'numpy'
import pandas as pd
import numpy as np
cars = pd.read_csv('cars.csv', index_col = 0)

# Crie a variável 'medium': linhas que possuem 'cars_per_cap' entre 100 e 500
cpc = cars['cars_per_cap']
between = np.logical_and(cpc > 100, cpc < 500)
medium = cars[between]

# Imprima 'medium'
print(medium)
# Out:
#     cars_per_cap country  drives_right
# RU           200  Russia          True
